# %%
# %load_ext autoreload
# %autoreload 2
import sys, os, json
root_path = os.path.abspath(os.path.join('..'))
sys.path.append(root_path)

# %%
from core.coach import gather_coach_context


context = gather_coach_context(12689416)
print(json.dumps(context, indent=4))
# Out:
# {
#     "athlete_profile": {
#         "ftp": 304,
#         "max_hr": 205
#     },
#     "fitness_summary": {
#         "current_ctl": 73.5,
#         "current_tsb": -20.94,
#         "ramp_rate_7d": 5.32,
#         "this_week_tss": 795.0,
#         "last_week_tss": 636.6,
#         "workload_delta_pct": 24.9
#     },
#     "fitness_trend_14d": [
#         {
#             "date": "2026-03-09",
#             "ctl": 63.82,
#             "atl": 80.13,
#             "tsb": -16.31
#         },
#         {
#             "date": "2026-03-10",
#             "ctl": 63.2,
#             "atl": 74.47,
#             "tsb": -11.26
#         },
#         {
#             "date": "2026-03-11",
#             "ctl": 66.71,
#             "atl": 92.78,
#             "tsb": -26.07
#         },
#         {
#             "date": "2026-03-12",
#             "ctl": 65.6,
#             "atl": 83.06,
#             "tsb": -17.46
#         },
#         {
#             "date": "2026-03-13",
#             "ctl": 67.81,
#             "atl": 93.24,
#             "tsb": -25.43
#         },
#         {
#             "date": "2026-03-14",
#             "ctl": 68.34,
#             "atl": 92.83,
#             "tsb": -24.5
#         },
#         {
#             "date": "2026-03-15",
#             "ctl": 67.42,
#             "atl": 84.36,
#             "tsb": -16.95
#         },
#         {
#             "date": "2026-03-16",
#             "ctl": 67.33,
#             "atl": 81.61,
#             "tsb": -14.28
#         },
#         {
#             "date": "2026-03-17",
#             "ctl": 68.18,
#             "atl": 84.5,
#             "tsb": -16.32
#         },
#         {
#             "date": "2026-03-18",
#             "ctl": 70.78,
#             "atl": 97.08,
#             "tsb": -26.3
#         },
#         {
#             "date": "2026-03-19",
#             "ctl": 72.85,
#             "atl": 105.26,
#             "tsb": -32.41
#         },
#         {
#             "date": "2026-03-20",
#             "ctl": 71.71,
#             "atl": 94.47,
#             "tsb": -22.76
#         },
#         {
#             "date": "2026-03-21",
#             "ctl": 72.33,
#             "atl": 94.95,
#             "tsb": -22.63
#         },
#         {
#             "date": "2026-03-22",
#             "ctl": 74.77,
#             "atl": 105.74,
#             "tsb": -30.98
#         },
#         {
#             "date": "2026-03-23",
#             "ctl": 73.5,
#             "atl": 94.43,
#             "tsb": -20.94
#         }
#     ],
#     "recent_activities": [
#         {
#             "date": "2026-03-23",
#             "name": "Lunch Weight Training",
#             "type": "WeightTraining",
#             "dur_min": 64,
#             "tss": 20.8,
#             "intensity": 0.44,
#             "decoupling_pct": 0.0,
#             "ef": 0.0,
#             "vi": null,
#             "peak_20m": null,
#             "power_tiz": {},
#             "hr_tiz": {
#                 "Z1": 1953,
#                 "Z2": 55,
#                 "Z3": 16
#             }
#         },
#         {
#             "date": "2026-03-22",
#             "name": "Morning Ride",
#             "type": "Ride",
#             "dur_min": 220,
#             "tss": 176.0,
#             "intensity": 0.69,
#             "decoupling_pct": 10.52,
#             "ef": 1.56,
#             "vi": null,
#             "peak_20m": 218,
#             "power_tiz": {
#                 "Z1": 5476,
#                 "Z2": 3989,
#                 "Z3": 2155,
#                 "Z4": 888,
#                 "Z5": 409,
#                 "Z6": 284,
#                 "Z7": 67
#             },
#             "hr_tiz": {
#                 "Z1": 3227,
#                 "Z2": 5634,
#                 "Z3": 3484,
#                 "Z4": 825,
#                 "Z5": 98
#             }
#         },
#         {
#             "date": "2026-03-21",
#             "name": "Evening Ride",
#             "type": "VirtualRide",
#             "dur_min": 77,
#             "tss": 98.1,
#             "intensity": 0.87,
#             "decoupling_pct": 9.77,
#             "ef": 1.74,
#             "vi": null,
#             "peak_20m": 267,
#             "power_tiz": {
#                 "Z1": 411,
#                 "Z2": 1617,
#                 "Z3": 40,
#                 "Z4": 2535,
#                 "Z5": 74
#             },
#             "hr_tiz": {
#                 "Z1": 733,
#                 "Z2": 1048,
#                 "Z3": 961,
#                 "Z4": 1935
#             }
#         },
#         {
#             "date": "2026-03-19",
#             "name": "Afternoon Ride",
#             "type": "Ride",
#             "dur_min": 210,
#             "tss": 158.5,
#             "intensity": 0.67,
#             "decoupling_pct": 7.72,
#             "ef": 1.56,
#             "vi": null,
#             "peak_20m": 223,
#             "power_tiz": {
#                 "Z1": 2783,
#                 "Z2": 5513,
#                 "Z3": 3438,
#                 "Z4": 498,
#                 "Z5": 178,
#                 "Z6": 198,
#                 "Z7": 8
#             },
#             "hr_tiz": {
#                 "Z1": 2652,
#                 "Z2": 6795,
#                 "Z3": 3169
#             }
#         },
#         {
#             "date": "2026-03-18",
#             "name": "Lunch Ride",
#             "type": "Ride",
#             "dur_min": 244,
#             "tss": 179.0,
#             "intensity": 0.66,
#             "decoupling_pct": 1.36,
#             "ef": 1.5,
#             "vi": null,
#             "peak_20m": 226,
#             "power_tiz": {
#                 "Z1": 3356,
#                 "Z2": 6914,
#                 "Z3": 3298,
#                 "Z4": 591,
#                 "Z5": 318,
#                 "Z6": 183,
#                 "Z7": 6
#             },
#             "hr_tiz": {
#                 "Z1": 2601,
#                 "Z2": 7507,
#                 "Z3": 4282,
#                 "Z4": 276
#             }
#         },
#         {
#             "date": "2026-03-17",
#             "name": "Afternoon Ride",
#             "type": "Ride",
#             "dur_min": 105,
#             "tss": 103.3,
#             "intensity": 0.77,
#             "decoupling_pct": 12.5,
#             "ef": 1.76,
#             "vi": null,
#             "peak_20m": 232,
#             "power_tiz": {
#                 "Z1": 1966,
#                 "Z2": 2168,
#                 "Z3": 1040,
#                 "Z4": 325,
#                 "Z5": 530,
#                 "Z6": 266,
#                 "Z7": 16
#             },
#             "hr_tiz": {
#                 "Z1": 1920,
#                 "Z2": 2977,
#                 "Z3": 672,
#                 "Z4": 700,
#                 "Z5": 42
#             }
#         },
#         {
#             "date": "2026-03-16",
#             "name": "6MVR",
#             "type": "Ride",
#             "dur_min": 51,
#             "tss": 59.3,
#             "intensity": 0.83,
#             "decoupling_pct": -21.39,
#             "ef": 1.74,
#             "vi": null,
#             "peak_20m": 207,
#             "power_tiz": {
#                 "Z1": 1793,
#                 "Z2": 491,
#                 "Z3": 382,
#                 "Z4": 289,
#                 "Z5": 209,
#                 "Z6": 216,
#                 "Z7": 131
#             },
#             "hr_tiz": {
#                 "Z1": 833,
#                 "Z2": 507,
#                 "Z3": 1268,
#                 "Z4": 700,
#                 "Z5": 203
#             }
#         },
#         {
#             "date": "2026-03-15",
#             "name": "Zwift - London",
#             "type": "VirtualRide",
#             "dur_min": 32,
#             "tss": 4.2,
#             "intensity": 0.28,
#             "decoupling_pct": -3.73,
#             "ef": 0.93,
#             "vi": null,
#             "peak_20m": 72,
#             "power_tiz": {
#                 "Z1": 1872,
#                 "Z2": 90,
#                 "Z3": 16,
#                 "Z5": 1
#             },
#             "hr_tiz": {
#                 "Z1": 1979
#             }
#         },
#         {
#             "date": "2026-03-15",
#             "name": "Morning Weight Training",
#             "type": "WeightTraining",
#             "dur_min": 81,
#             "tss": 25.0,
#             "intensity": 0.43,
#             "decoupling_pct": 0.0,
#             "ef": 0.0,
#             "vi": null,
#             "peak_20m": null,
#             "power_tiz": {},
#             "hr_tiz": {
#                 "Z1": 2655,
#                 "Z2": 52
#             }
#         },
#         {
#             "date": "2026-03-14",
#             "name": "Lunch Ride",
#             "type": "Ride",
#             "dur_min": 93,
#             "tss": 90.2,
#             "intensity": 0.76,
#             "decoupling_pct": 18.54,
#             "ef": 1.76,
#             "vi": null,
#             "peak_20m": 247,
#             "power_tiz": {
#                 "Z1": 2487,
#                 "Z2": 1600,
#                 "Z3": 744,
#                 "Z4": 260,
#                 "Z5": 328,
#                 "Z6": 137,
#                 "Z7": 44
#             },
#             "hr_tiz": {
#                 "Z1": 1935,
#                 "Z2": 2033,
#                 "Z3": 1178,
#                 "Z4": 281,
#                 "Z5": 173
#             }
#         },
#         {
#             "date": "2026-03-13",
#             "name": "Lunch Ride",
#             "type": "Ride",
#             "dur_min": 201,
#             "tss": 159.5,
#             "intensity": 0.69,
#             "decoupling_pct": -3.11,
#             "ef": 1.48,
#             "vi": null,
#             "peak_20m": 229,
#             "power_tiz": {
#                 "Z1": 1772,
#                 "Z2": 6557,
#                 "Z3": 3047,
#                 "Z4": 398,
#                 "Z5": 177,
#                 "Z6": 164,
#                 "Z7": 11
#             },
#             "hr_tiz": {
#                 "Z1": 948,
#                 "Z2": 4137,
#                 "Z3": 6989,
#                 "Z4": 52
#             }
#         },
#         {
#             "date": "2026-03-12",
#             "name": "Morning Weight Training",
#             "type": "WeightTraining",
#             "dur_min": 64,
#             "tss": 19.8,
#             "intensity": 0.43,
#             "decoupling_pct": 0.0,
#             "ef": 0.0,
#             "vi": null,
#             "peak_20m": null,
#             "power_tiz": {},
#             "hr_tiz": {
#                 "Z1": 2068,
#                 "Z2": 12
#             }
#         },
#         {
#             "date": "2026-03-11",
#             "name": "Morning Ride",
#             "type": "Ride",
#             "dur_min": 318,
#             "tss": 212.0,
#             "intensity": 0.63,
#             "decoupling_pct": -1.69,
#             "ef": 1.46,
#             "vi": null,
#             "peak_20m": 210,
#             "power_tiz": {
#                 "Z1": 3968,
#                 "Z2": 11846,
#                 "Z3": 2474,
#                 "Z4": 320,
#                 "Z5": 286,
#                 "Z6": 200,
#                 "Z7": 2
#             },
#             "hr_tiz": {
#                 "Z1": 3567,
#                 "Z2": 12817,
#                 "Z3": 2682,
#                 "Z4": 30
#             }
#         },
#         {
#             "date": "2026-03-10",
#             "name": "Lunch Ride",
#             "type": "Ride",
#             "dur_min": 79,
#             "tss": 37.6,
#             "intensity": 0.53,
#             "decoupling_pct": 0.03,
#             "ef": 1.4,
#             "vi": null,
#             "peak_20m": 166,
#             "power_tiz": {
#                 "Z1": 2476,
#                 "Z2": 1902,
#                 "Z3": 263,
#                 "Z4": 93,
#                 "Z5": 39,
#                 "Z6": 10
#             },
#             "hr_tiz": {
#                 "Z1": 3109,
#                 "Z2": 1667,
#                 "Z3": 7
#             }
#         },
#         {
#             "date": "2026-03-09",
#             "name": "6MVR",
#             "type": "Ride",
#             "dur_min": 52,
#             "tss": 66.3,
#             "intensity": 0.87,
#             "decoupling_pct": 8.36,
#             "ef": 1.62,
#             "vi": null,
#             "peak_20m": 255,
#             "power_tiz": {
#                 "Z1": 841,
#                 "Z2": 589,
#                 "Z3": 603,
#                 "Z4": 445,
#                 "Z5": 315,
#                 "Z6": 289,
#                 "Z7": 69
#             },
#             "hr_tiz": {
#                 "Z1": 170,
#                 "Z2": 102,
#                 "Z3": 1082,
#                 "Z4": 1413,
#                 "Z5": 384
#             }
#         },
#         {
#             "date": "2026-03-09",
#             "name": "Afternoon Weight Training",
#             "type": "WeightTraining",
#             "dur_min": 62,
#             "tss": 22.0,
#             "intensity": 0.46,
#             "decoupling_pct": 0.0,
#             "ef": 0.0,
#             "vi": null,
#             "peak_20m": null,
#             "power_tiz": {},
#             "hr_tiz": {
#                 "Z1": 1612,
#                 "Z2": 48
#             }
#         }
#     ]
# }

# %%
import json
from core.coach import get_coaching_advice

athlete_id = 12689416

print(f"--- Consulting Coach Gemini for Athlete: {athlete_id} ---")

try:
    # Get the dictionary from the AI
    advice = get_coaching_advice(athlete_id, debug=False)
    
    print("\n" + "="*40)
    print("COPY THE BLOCK BELOW FOR DEBUG_OUTPUT")
    print("="*40 + "\n")
    
    # Use indent=4 to make it readable and ensure it's valid for pasting
    print(json.dumps(advice, indent=4))
    
    print("\n" + "="*40)
    
except Exception as e:
    print(f"Error during test: {e}")
# Out:
# --- Consulting Coach Gemini for Athlete: 12689416 ---
# helloooooo
#
# ========================================
# COPY THE BLOCK BELOW FOR DEBUG_OUTPUT
# ========================================
#
# {
#     "status": "You are currently deep in a build phase, indicated by a significantly negative TSB of -20.94 and a substantial week-over-week TSS increase.",
#     "insights": [
#         "You've executed a 24.9% increase in TSS this week compared to last.",
#         "Aerobic durability shows signs of compromise with decoupling at 10.52%.",
#         "Longer endurance rides contain too much Z4-Z6 intensity."
#     ],
#     "recommendation": {
#         "target": "Prioritize active recovery. 60-90 minute Zone 1-2 ride.",
#         "alternative": "Focus solely on recovery or a very light 30-minute Z1 spin."
#     },
#     "metrics_flagged": [
#         "volume_spike",
#         "high_decoupling",
#         "high_fatigue"
#     ]
# }
#
# ========================================
