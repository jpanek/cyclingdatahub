# %%
query = """
select 
 u.firstname, u.athlete_id, max(ca.strava_id) lst_strava_id, count(*) cnt, max(ca.generated_at) time
from coach_advice ca 
join users u on u.athlete_id  = ca.athlete_id 
group by u.firstname, u.athlete_id
order by 5 desc
"""
from core.database import run_query_pd
results = run_query_pd(query)

display(results)
# Out:
# /Users/jurajpanek/Documents/code/cycling_stats/core/database.py:107: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   return pd.read_sql_query(query, conn, params=params)
#   firstname  athlete_id  lst_strava_id  cnt                       time
# 0     Juraj    12689416    17842263350    1 2026-03-25 19:47:22.847587
# 1   Vojtěch     5292492    17832485385    1 2026-03-25 14:00:21.541150
# 2       Jon    23331177    17850121892    1 2026-03-25 13:46:02.976743
# 3    Martin     1252419    17832395799    1 2026-03-25 12:22:46.040739
