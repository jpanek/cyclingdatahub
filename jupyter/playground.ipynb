# %%
# %load_ext autoreload
# %autoreload 2
import sys, os
root_path = os.path.abspath(os.path.join('..'))
sys.path.append(root_path)

# %%
from core.processor import process_activity_metrics

process_activity_metrics(17780575988,force=True)
# Out:
# True
