# %%
# %load_ext autoreload
# %autoreload 2
import sys, os, json
root_path = os.path.abspath(os.path.join('..'))
sys.path.append(root_path)

# %%
# %load_ext autoreload
# %autoreload 2
from core.coach import gather_coach_context


context = gather_coach_context(12689416)
print(json.dumps(context, indent=4))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {
#     "metadata": {
#         "history_days_analyzed": 14,
#         "analysis_date": "2026-03-30"
#     },
#     "athlete_profile": {
#         "ftp": 310,
#         "max_hr": 208
#     },
#     "fitness_summary": {
#         "current_ctl": 76,
#         "current_tsb": -11,
#         "tsb_min_in_period": -40,
#         "ramp_rate_7d": -2.5,
#         "this_week_total_tss": 648,
#         "prev_week_total_tss": 774,
#         "workload_delta_pct": -16
#     },
#     "fitness_trend_7d": [
#         {
#             "date": "2026-03-24",
#             "ctl": 78.28,
#             "atl": 118.16,
#             "tsb": -39.88
#         },
#         {
#             "date": "2026-03-25",
#             "ctl": 76.44,
#             "atl": 102.43,
#             "tsb": -25.99
#         },
#         {
#             "date": "2026-03-26",
#             "ctl": 76.57,
#             "atl": 99.68,
# ...

# %%
# %load_ext autoreload
# %autoreload 2
    
import json
from core.coach import get_coaching_advice

athlete_id = 12689416

print(f"--- Consulting Coach Gemini for Athlete: {athlete_id} ---")

try:
    # Get the dictionary from the AI
    advice = get_coaching_advice(athlete_id, debug=False)
    
    print(json.dumps(advice, indent=4))
    
except Exception as e:
    print(f"Error during test: {e}")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# --- Consulting Coach Gemini for Athlete: 12689416 ---
# {
#     "status": [
#         "You are currently in a heavy training block, indicated by a significant increase in weekly TSS and a negative TSB.",
#         "Accumulated fatigue is high, with TSB consistently negative and recent dips below -30.",
#         "The 7-day ramp rate shows a sustained increase in training load, contributing to your current fatigue state."
#     ],
#     "insights": [
#         "Your workload has increased by 27.3% this week compared to last, a substantial spike that elevates fatigue and recovery demands.",
#         "Recent endurance rides, particularly on March 23 (14.2%), March 22 (10.52%), and March 14 (18.54%), show elevated power-to-heart rate decoupling, indicating reduced aerobic efficiency or significant fatigue.",
# ...

# %%
# force re-run analytics on a given actvity:

from core.processor import process_activity_metrics

process_activity_metrics(strava_id=17829097537,force=True)
# Out:
# True
