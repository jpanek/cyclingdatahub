# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from core.processor import process_activity_metrics

strava_id = 17842263350

process_activity_metrics(strava_id = strava_id, force=True)
# Out:
# {'athlete_id': 12689416, 'type': 'Ride', 'start_date_local': datetime.datetime(2026, 3, 24, 11, 8, 36), 'strava_id': 17842263350, 'moving_time': 19715, 'elapsed_time': 21975, 'distance': 161366.0, 'total_elevation_gain': 1037.0, 'manual_ftp': None, 'detected_ftp': 304, 'ftp_detected_at': datetime.datetime(2026, 2, 10, 19, 3, 14), 'manual_max_hr': 208, 'detected_max_hr': 205, 'hr_detected_at': datetime.datetime(2026, 2, 16, 19, 48, 9), 'manual_ftp_updated_at': None, 'manual_max_hr_updated_at': datetime.datetime(2026, 3, 23, 18, 47, 12, 805000)}
# FTP: Calculated (304W)
# HR: Manual (208bpm)
# True
